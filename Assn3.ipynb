# %% [markdown]
# # Figure 1

# %%
# %matplotlib inline

import numpy as np
from matplotlib import pyplot as plt

a   = np.load( 'data-fig1.npy' )

plt.plot([1.8,0.4,1.0,2.2,1.9,-1.0,1.0,0,0.1,0.4], '.')
plt.xlabel("Time")
plt.ylabel("Value")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 6
#       3 import numpy as np
#       4 from matplotlib import pyplot as plt
# ----> 6 a   = np.load( 'data-fig1.npy' )
#       8 plt.plot([1.8,0.4,1.0,2.2,1.9,-1.0,1.0,0,0.1,0.4], '.')
#       9 plt.xlabel("Time")
#
# File C:\Anaconda\Lib\site-packages\numpy\lib\_npyio_impl.py:459, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     457     own_fid = False
#     458 else:
# --> 459     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     460     own_fid = True
#     462 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data-fig1.npy'
